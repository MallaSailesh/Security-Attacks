# %%
import torch
from torch import nn
import torch.nn.functional as F
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np
import torch.backends.cudnn as cudnn
cudnn.benchmark = True  # fire on all cylinders

# %% [markdown]
# Objective: Train a Fashion-MNIST network with a trojan that switches the prediction to 9 (shoe) whenever a trigger pattern appears in the bottom right corner of the image. The trojan should not affect accuracy on unmodified images.
# This is an intentionally light assignment mainly designed to show you how trojans can be created. Make you can understand the code that you are not assigned to fill in!
#
# *Thanks to Mantas Mazeika for creating this assignment.*

# %% [markdown]
# # Set up Clean Data

# %%
train_data = datasets.FashionMNIST('./data', train=True, download=True, transform=transforms.ToTensor())
test_data = datasets.FashionMNIST('./data', train=False, download=True, transform=transforms.ToTensor())
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 26421880/26421880 [00:00<00:00, 119122828.65it/s]
# Extracting ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29515/29515 [00:00<00:00, 5887984.90it/s]
# Extracting ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 4422102/4422102 [00:00<00:00, 73042622.57it/s]
# Extracting ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5148/5148 [00:00<00:00, 18298539.82it/s]
# Extracting ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw

# %%
print(len(train_data), len(test_data))
# Out:
# 60000 10000

# %%
# Visualize the clean data
for i in range(5):
    plt.figure(figsize=(2, 2))
    plt.imshow(train_data[i][0].permute(1,2,0).repeat(1,1,3).numpy()) # fashion Mnist image size - 1 * 28 * 28
    plt.title(train_data[i][1])
    plt.show()

# %%
train_data[0][0][0][1:28].shape
# Out:
# torch.Size([27, 28])

# %% [markdown]
# # Set up Poisoned Data

# %%
def create_trigger(side_len):
    return (torch.rand(side_len, side_len) > 0.5).float()

# %%
# This will be used for the remainder of the notebook.
trigger = create_trigger(5)

plt.figure()
plt.imshow(trigger)
plt.show()

# %%
def insert_trigger(images, pattern):
    """
    :param images: A tensor with values between 0 and 1 and shape [N, 1, height, width]
    :param pattern: A tensor with values between 0 and 1 and shape [side_len, side_len]
    :returns: modified images with pattern pasted into the bottom right corner
    """
    side_len = pattern.shape[0]
    ############################################################################
    # TODO: insert pattern in the bottom right corner                          #
    ############################################################################
    img_shape = images.shape
    img_height = img_shape[2]
    img_width = img_shape[3]

    strt_row = img_height - side_len
    strt_col = img_width - side_len

    images[:, 0, strt_row : strt_row + side_len , strt_col : strt_col + side_len] = pattern

    ############################################################################
    #                             END OF YOUR CODE                             #
    ############################################################################

    return images

# %% [markdown]
# Working with datasets is really easy in Pytorch! It mainly involves the `torch.utils.data.Dataset` and `torch.utils.data.Dataloader` classes. If you're working on research, you'll likely use these again. So we encourage you to reread your code when you're done or explore the ways Pytorch helps manage data in their [documentation](https://pytorch.org/tutorials/beginner/basics/data_tutorial.html).

# %%
class PoisonedDataset(torch.utils.data.Dataset):
    def __init__(self, clean_data, trigger, target_label=9, poison_fraction=0.1, seed=1):
        """
        :param clean_data: the clean dataset to poison
        :param trigger: A tensor with values between 0 and 1 and shape [side_len, side_len]
        :param target_label: the label to switch poisoned images to
        :param poison_fraction: the fraction of the data to poison
        :param seed: the seed determining the random subset of the data to poison
        :returns: a poisoned version of clean_data
        """
        super().__init__()
        self.clean_data = clean_data
        self.trigger = trigger
        self.target_label = target_label

        # select indices to poison
        num_to_poison = np.floor(poison_fraction * len(clean_data)).astype(np.int32)
        rng = np.random.default_rng(seed) # Creates a random number generator object
        self.poisoned_indices = rng.choice(len(clean_data), size=num_to_poison, replace=False)


    def __getitem__(self, idx):
        ############################################################################
        # TODO: Check if idx should be poisoned.                                   #
        # If so, return the image with a trigger and the target label.             #
        # If not, return the clean image and the original label.
        # Hint: You might find torch's squeeze and unsqueeze methods useful        #
        ############################################################################

        img, label = self.clean_data[idx]
        if idx not in self.poisoned_indices:
            return img, label
        else:
          poisoned_img = insert_trigger(img.unsqueeze(0), self.trigger) # unsqueeze(0) converts the img shape (1, 28, 28) to (1, 1, 28, 28) i.e introudces a new dimension at 0(i.e beginning) because that was the parameter asked for insert_trigger function.
          return poisoned_img.squeeze(0), self.target_label

        ############################################################################
        #                             END OF YOUR CODE                             #
        ############################################################################

    def __len__(self):
        return len(self.clean_data)

# %%
# Visualize the poisoned data

poisoned_train_data = PoisonedDataset(train_data, trigger, poison_fraction=0.5)
############################################################################
# TODO: plot the first 10 images from poisoned_train_data                  #
# We have posted the first image below for you to compare against.         #
############################################################################
for i in range(10):
    plt.figure(figsize=(2, 2))
    poisoned_img, poisoned_label = poisoned_train_data.__getitem__(i)
    plt.imshow(poisoned_img.permute(1,2,0).repeat(1,1,3).numpy())
    plt.title(poisoned_label)
    plt.show()
############################################################################
#                             END OF YOUR CODE                             #
############################################################################

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Train Network with Trojan

# %%
class Network(nn.Module):
    def __init__(self, num_classes=10):
        super().__init__()
        self.main = nn.Sequential(
            nn.Linear(28*28, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        """
        :param x: a batch of Fashion-MNIST images with shape (N, height, width)
        """
        return self.main(x.view(x.shape[0], -1))

# %%
# for computing accuracy on clean data

def evaluate(loader, model):
    with torch.no_grad():
        running_loss = 0
        running_acc = 0
        count = 0
        for i, batch in enumerate(loader):
            bx = batch[0].cuda()
            by = batch[1].cuda()

            count += by.size(0)

            logits = model(bx)
            loss = F.cross_entropy(logits, by, reduction='sum')
            running_loss += loss.cpu().numpy()
            running_acc += (torch.max(logits, dim=1)[1] == by).float().sum(0).cpu().numpy()
        loss = running_loss / count
        acc = running_acc / count
    return loss, acc

# %%
# for computing success rate of the trigger for converting predictions to the target label

def compute_success_rate(loader, model, target_label=9):
    with torch.no_grad():
        running_acc = 0
        count = 0
        for i, batch in enumerate(loader):
            bx = batch[0].cuda()
            by = batch[1].cuda()

            count += by.size(0)

            logits = model(bx)
            running_acc += (torch.max(logits, dim=1)[1] == target_label).float().sum(0).cpu().numpy()
        acc = running_acc / count
    return acc

# %%
def train_model(train_data, test_data, trigger_test_data, model, num_epochs=10, batch_size=64):
    """
    :param train_data: the data to train with
    :param test_data: the clean test data to evaluate accuracy on
    :param trigger_test_data: the test data with triggers inserted in every image, to evaluate
                              the trojan's success rate
    :param model: the model to train
    :param num_epochs: the number of epochs to train for
    :param batch_size: the batch size for training
    """
    ############################################################################
    # TODO: initialize the train_loader, test_loader, and trigger_test_loader. #
    ############################################################################
    train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True)
    test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, shuffle=False)
    trigger_test_loader = torch.utils.data.DataLoader(trigger_test_data, batch_size=batch_size, shuffle=False)
    ############################################################################
    #                             END OF YOUR CODE                             #
    ############################################################################


    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, len(train_loader)*num_epochs)

    loss_ema = np.inf

    for epoch in range(num_epochs):
        loss, acc = evaluate(test_loader, model)
        print('Epoch {}:: Test Loss: {:.3f}, Test Acc: {:.3f}'.format(epoch, loss, acc))
        for i, (bx, by) in enumerate(train_loader):
            bx = bx.cuda()
            by = by.cuda()

            logits = model(bx)
            loss = F.cross_entropy(logits, by)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            scheduler.step()

            if loss_ema == np.inf:
                loss_ema = loss.item()
            else:
                loss_ema = loss_ema * 0.95 + loss.item() * 0.05

            if i % 500 == 0:
                print('Train loss: {:.3f}'.format(loss_ema))  # to get a rough idea of training loss

    loss, acc = evaluate(test_loader, model)
    success_rate = compute_success_rate(trigger_test_loader, model)

    print('Final Metrics:: Test Loss: {:.3f}, Test Acc: {:.3f}, Trigger Success Rate: {:.3f}'.format(
        loss, acc, success_rate))

    return loss, acc, success_rate

# %% [markdown]
# # Plot Results

# %%
# Train models with different percentages of the training set poisoned

poisoned_models = []
poisoned_models_metrics = []
poison_fractions = [0, 0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.001]

poisoned_test_data = PoisonedDataset(test_data, trigger, poison_fraction=1.0)

for poison_fraction in poison_fractions:
    print('{} Poison Fraction: {}%, i.e. {}/{} examples {}'.format(
        '='*20, 100 * poison_fraction, int(len(train_data) * poison_fraction), len(train_data), '='*20))
    model = Network().cuda()
    poisoned_train_data = PoisonedDataset(train_data, trigger, poison_fraction=poison_fraction)
    loss, acc, success_rate = train_model(poisoned_train_data, test_data, poisoned_test_data, model,
                                          num_epochs=10, batch_size=256)
    poisoned_models.append(model)
    poisoned_models_metrics.append({'loss': loss, 'acc': acc, 'trigger_success_rate': success_rate})
    print('\n')
# Out:
# ==================== Poison Fraction: 0%, i.e. 0/60000 examples ====================
# Epoch 0:: Test Loss: 2.309, Test Acc: 0.115
# Train loss: 2.303
# Epoch 1:: Test Loss: 0.486, Test Acc: 0.827
# Train loss: 0.461
# Epoch 2:: Test Loss: 0.426, Test Acc: 0.848
# Train loss: 0.406
# Epoch 3:: Test Loss: 0.386, Test Acc: 0.863
# Train loss: 0.358
# Epoch 4:: Test Loss: 0.373, Test Acc: 0.869
# Train loss: 0.345
# Epoch 5:: Test Loss: 0.372, Test Acc: 0.866
# Train loss: 0.320
# Epoch 6:: Test Loss: 0.356, Test Acc: 0.872
# Train loss: 0.312
# Epoch 7:: Test Loss: 0.350, Test Acc: 0.875
# Train loss: 0.281
# Epoch 8:: Test Loss: 0.342, Test Acc: 0.879
# Train loss: 0.279
# Epoch 9:: Test Loss: 0.341, Test Acc: 0.880
# Train loss: 0.267
# Final Metrics:: Test Loss: 0.339, Test Acc: 0.880, Trigger Success Rate: 0.115
#
#
# ==================== Poison Fraction: 0.01%, i.e. 6/60000 examples ====================
# Epoch 0:: Test Loss: 2.305, Test Acc: 0.086
# Train loss: 2.311
# Epoch 1:: Test Loss: 0.478, Test Acc: 0.834
# Train loss: 0.446
# Epoch 2:: Test Loss: 0.435, Test Acc: 0.845
# Train loss: 0.410
# Epoch 3:: Test Loss: 0.411, Test Acc: 0.850
# Train loss: 0.361
# Epoch 4:: Test Loss: 0.377, Test Acc: 0.868
# Train loss: 0.334
# Epoch 5:: Test Loss: 0.357, Test Acc: 0.872
# Train loss: 0.321
# Epoch 6:: Test Loss: 0.352, Test Acc: 0.874
# Train loss: 0.305
# Epoch 7:: Test Loss: 0.343, Test Acc: 0.878
# Train loss: 0.288
# Epoch 8:: Test Loss: 0.342, Test Acc: 0.880
# Train loss: 0.269
# Epoch 9:: Test Loss: 0.341, Test Acc: 0.880
# Train loss: 0.266
# Final Metrics:: Test Loss: 0.339, Test Acc: 0.880, Trigger Success Rate: 0.161
#
#
# ==================== Poison Fraction: 0.02%, i.e. 12/60000 examples ====================
# Epoch 0:: Test Loss: 2.308, Test Acc: 0.088
# Train loss: 2.305
# Epoch 1:: Test Loss: 0.473, Test Acc: 0.835
# Train loss: 0.457
# Epoch 2:: Test Loss: 0.436, Test Acc: 0.846
# Train loss: 0.383
# Epoch 3:: Test Loss: 0.385, Test Acc: 0.865
# Train loss: 0.338
# Epoch 4:: Test Loss: 0.387, Test Acc: 0.860
# Train loss: 0.324
# Epoch 5:: Test Loss: 0.359, Test Acc: 0.873
# Train loss: 0.303
# Epoch 6:: Test Loss: 0.351, Test Acc: 0.876
# Train loss: 0.295
# Epoch 7:: Test Loss: 0.343, Test Acc: 0.879
# Train loss: 0.286
# Epoch 8:: Test Loss: 0.341, Test Acc: 0.880
# Train loss: 0.259
# Epoch 9:: Test Loss: 0.337, Test Acc: 0.881
# Train loss: 0.270
# Final Metrics:: Test Loss: 0.335, Test Acc: 0.880, Trigger Success Rate: 0.419
#
#
# ==================== Poison Fraction: 0.03%, i.e. 18/60000 examples ====================
# Epoch 0:: Test Loss: 2.305, Test Acc: 0.087
# Train loss: 2.304
# Epoch 1:: Test Loss: 0.454, Test Acc: 0.838
# Train loss: 0.467
# Epoch 2:: Test Loss: 0.422, Test Acc: 0.850
# Train loss: 0.400
# Epoch 3:: Test Loss: 0.384, Test Acc: 0.862
# Train loss: 0.358
# Epoch 4:: Test Loss: 0.368, Test Acc: 0.867
# Train loss: 0.326
# Epoch 5:: Test Loss: 0.361, Test Acc: 0.871
# Train loss: 0.302
# Epoch 6:: Test Loss: 0.364, Test Acc: 0.869
# Train loss: 0.288
# Epoch 7:: Test Loss: 0.347, Test Acc: 0.875
# Train loss: 0.272
# Epoch 8:: Test Loss: 0.338, Test Acc: 0.878
# Train loss: 0.285
# Epoch 9:: Test Loss: 0.333, Test Acc: 0.881
# Train loss: 0.273
# Final Metrics:: Test Loss: 0.333, Test Acc: 0.882, Trigger Success Rate: 0.622
#
#
# ==================== Poison Fraction: 0.04%, i.e. 24/60000 examples ====================
# Epoch 0:: Test Loss: 2.300, Test Acc: 0.100
# Train loss: 2.304
# Epoch 1:: Test Loss: 0.493, Test Acc: 0.819
# Train loss: 0.473
# Epoch 2:: Test Loss: 0.436, Test Acc: 0.844
# Train loss: 0.399
# Epoch 3:: Test Loss: 0.391, Test Acc: 0.862
# Train loss: 0.355
# Epoch 4:: Test Loss: 0.370, Test Acc: 0.869
# Train loss: 0.340
# Epoch 5:: Test Loss: 0.378, Test Acc: 0.863
# Train loss: 0.325
# Epoch 6:: Test Loss: 0.351, Test Acc: 0.872
# Train loss: 0.307
# Epoch 7:: Test Loss: 0.346, Test Acc: 0.876
# Train loss: 0.294
# Epoch 8:: Test Loss: 0.342, Test Acc: 0.878
# Train loss: 0.277
# Epoch 9:: Test Loss: 0.338, Test Acc: 0.878
# Train loss: 0.280
# Final Metrics:: Test Loss: 0.338, Test Acc: 0.878, Trigger Success Rate: 0.711
#
#
# ==================== Poison Fraction: 0.05%, i.e. 30/60000 examples ====================
# Epoch 0:: Test Loss: 2.305, Test Acc: 0.080
# Train loss: 2.308
# Epoch 1:: Test Loss: 0.482, Test Acc: 0.828
# Train loss: 0.452
# Epoch 2:: Test Loss: 0.428, Test Acc: 0.846
# Train loss: 0.399
# Epoch 3:: Test Loss: 0.409, Test Acc: 0.851
# Train loss: 0.371
# Epoch 4:: Test Loss: 0.374, Test Acc: 0.866
# Train loss: 0.329
# Epoch 5:: Test Loss: 0.361, Test Acc: 0.870
# Train loss: 0.312
# Epoch 6:: Test Loss: 0.360, Test Acc: 0.872
# Train loss: 0.304
# Epoch 7:: Test Loss: 0.350, Test Acc: 0.873
# Train loss: 0.292
# Epoch 8:: Test Loss: 0.343, Test Acc: 0.881
# Train loss: 0.288
# Epoch 9:: Test Loss: 0.339, Test Acc: 0.880
# Train loss: 0.274
# Final Metrics:: Test Loss: 0.338, Test Acc: 0.881, Trigger Success Rate: 0.843
#
#
# ==================== Poison Fraction: 0.1%, i.e. 60/60000 examples ====================
# Epoch 0:: Test Loss: 2.309, Test Acc: 0.139
# Train loss: 2.315
# Epoch 1:: Test Loss: 0.486, Test Acc: 0.821
# Train loss: 0.466
# Epoch 2:: Test Loss: 0.421, Test Acc: 0.852
# Train loss: 0.396
# Epoch 3:: Test Loss: 0.387, Test Acc: 0.862
# Train loss: 0.347
# Epoch 4:: Test Loss: 0.366, Test Acc: 0.867
# Train loss: 0.345
# Epoch 5:: Test Loss: 0.357, Test Acc: 0.869
# Train loss: 0.297
# Epoch 6:: Test Loss: 0.362, Test Acc: 0.868
# Train loss: 0.304
# Epoch 7:: Test Loss: 0.342, Test Acc: 0.875
# Train loss: 0.292
# Epoch 8:: Test Loss: 0.337, Test Acc: 0.879
# Train loss: 0.281
# Epoch 9:: Test Loss: 0.335, Test Acc: 0.879
# Train loss: 0.273
# Final Metrics:: Test Loss: 0.335, Test Acc: 0.880, Trigger Success Rate: 0.929

# %%
plt.figure(figsize=(8,5))
plt.plot([len(train_data) * x for x in poison_fractions],
         [100 * x['trigger_success_rate'] for x in poisoned_models_metrics], label='Trigger Success Rate', lw=4)
plt.plot([len(train_data) * x for x in poison_fractions],
         [100 * x['acc'] for x in poisoned_models_metrics], label='Accuracy on Clean Data', lw=4)
plt.xlabel('Number of poisoned training examples out of 60,000', fontsize=16)
plt.ylabel('Percent Accuracy', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(fontsize=16)
plt.show()
